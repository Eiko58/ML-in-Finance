# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
import torch

# %% [markdown]
# ## **European Option**

# %%
class EuropeanCallOption(object):
    def __init__(self, S0, K, r, T, sigma,M,I):
        self.S0 = S0
        self.K = K
        self.r = r
        self.T = T
        self.sigma = sigma
        self.M = M
        self.I = I
    #Write the option pricing
    #def value(self):

    #Write the simulation function
    #def simulation(self):

# %%
prices,payoff = EuropeanCallOption(100, 105, 0.05, 1.0, 0.2, 5000, 1000).simulation()
plt.scatter(prices[-1],payoff[-1])
plt.grid()

# %% [markdown]
# ## **Digital Option**

# %%
class DigitalCallOption(object):
    def __init__(self, S0, K, r, T, sigma,Q, M, I):
        self.S0 = S0
        self.K = K
        self.r = r
        self.T = T
        self.sigma = sigma
        self.Q = Q
        self.M = M
        self.I = I
    #Write the option pricing
    #def value(self):

    #Write the simulation function
    #def simulation(self):

# %%
prices,payoff = DigitalCallOption(100, 105, 0.05, 1.0, 0.2,5,5000,1000).simulation()
plt.scatter(prices[-1],payoff[-1])
plt.grid()

# %% [markdown]
# ## **Heston Model Simulation**

# %%
class HestonModel(object):
    def __init__(self, S0, K, r, T, sigma, rho, kappa, theta, xi, M, I):
        self.S0 = S0
        self.K = K
        self.r = r
        self.T = T
        self.sigma = sigma
        self.rho = rho
        self.kappa = kappa
        self.theta = theta
        self.xi = xi
        self.M = M
        self.I = I
    #Write the heston simulation
    #def heston_paths(self):

    #Pricing options with Heston model
    #def value(self):

# %%
S_p,V_p = s,v = HestonModel(100, 100, 0.05, 1.0, 0.2, 0.7, 2.0, 0.05, 0.3, 500, 1000).heston_paths()
S_n,V_n = s,v = HestonModel(100, 100, 0.05, 1.0, 0.2, -0.7, 2.0, 0.05, 0.3, 500, 1000).heston_paths()

# %%
plt.plot(S_p[:,-1])
plt.plot(S_n[:,-1])
